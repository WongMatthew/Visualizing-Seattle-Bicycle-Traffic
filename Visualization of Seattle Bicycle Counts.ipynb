# %% [markdown]
# # Visualization of Seattle Bicycle Counts w/ time series concepts
#
# Dataset can be found [**here**](https://data.seattle.gov/Transportation/Fremont-Bridge-Bicycle-Counter/65db-xm6k)

# %%
import pandas as pd
data = pd.read_csv('FremontBridge.csv', index_col='Date', parse_dates=True)
data.head()
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# Date
# 2019-11-01 00:00:00                  12.0                           7.0
# 2019-11-01 01:00:00                   7.0                           0.0
# 2019-11-01 02:00:00                   1.0                           0.0
# 2019-11-01 03:00:00                   6.0                           6.0
# 2019-11-01 04:00:00                   6.0                           5.0
#
#                      Fremont Bridge West Sidewalk
# Date
# 2019-11-01 00:00:00                           5.0
# 2019-11-01 01:00:00                           7.0
# 2019-11-01 02:00:00                           1.0
# 2019-11-01 03:00:00                           0.0
# 2019-11-01 04:00:00                           1.0

# %%
data.dropna().describe()
# Out:
#        Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# count         143608.000000                 143608.000000
# mean             111.162735                     50.547616
# std              141.443433                     65.157096
# min                0.000000                      0.000000
# 25%               14.000000                      6.000000
# 50%               60.000000                     28.000000
# 75%              146.000000                     68.000000
# max             1097.000000                    698.000000
#
#        Fremont Bridge West Sidewalk
# count                 143608.000000
# mean                      60.615119
# std                       87.921215
# min                        0.000000
# 25%                        7.000000
# 50%                       30.000000
# 75%                       74.000000
# max                      850.000000

# %%
# %matplotlib inline
import seaborn; seaborn.set()
import matplotlib.pyplot as plt

# %%
# plot raw data

data.plot()
plt.ylabel('Hourly Bicycle Count');

# %%
# resample by week and plot

weekly = data.resample('W').sum()
weekly.plot(style=[':', '--', '-'])
plt.ylabel('Weekly bicycle count');

# %%
# get 30day rolling mean and plot

daily = data.resample('D').sum()
daily.rolling(30, center=True).sum().plot(style=[':', '--', '-'])
plt.ylabel('mean hourly count');

# %%
# smooth it out by extending the window and the classifier

daily.rolling(50, center=True,
              win_type='gaussian').sum(std=10).plot(style=[':', '--', '-']);

# %%
# view average traffic by time of day

import numpy as np
by_time = data.groupby(data.index.time).mean()
hourly_ticks = 4 * 60 * 60 * np.arange(6)
by_time.plot(xticks=hourly_ticks, style=[':', '--', '-']);

# %%
# view traffic by day of the week

by_weekday = data.groupby(data.index.dayofweek).mean()
by_weekday.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
by_weekday.plot(style=[':', '--', '-']);
# Out:
# C:\Users\Matthew Wong\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
# view the hourly traffic trends - weekdays vs weekends

weekend = np.where(data.index.weekday < 5, 'Weekday', 'Weekend')
by_time = data.groupby([weekend, data.index.time]).mean()

fig, ax = plt.subplots(1, 2, figsize=(14, 5))
by_time.loc['Weekday'].plot(ax=ax[0], title='Weekdays',
                           xticks=hourly_ticks, style=[':', '--', '-'])
by_time.loc['Weekend'].plot(ax=ax[1], title='Weekends',
                           xticks=hourly_ticks, style=[':', '--', '-']);
